# %% [markdown]
# <a href="https://colab.research.google.com/github/jkeconr/datawork/blob/main/data_NABO_KH_230112.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# # 코드로 형식 지정됨
# ```
#
# ## Dataset for NABO_KH
# ##### last updated: Jan 13, 2023

# %%
# import libraries

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.pylab as plt
import datetime as dt
import os
import warnings
import requests # python 3.6

import statsmodels.api as sm
from statsmodels.tsa.seasonal import STL

import pandas_datareader as pdr
import pandas_datareader.data as web
from pandas_datareader import wb
from pandas_datareader.data import DataReader

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# set the working directory

os.chdir('/content/gdrive/MyDrive/Colab Notebooks/datawork')

# %% [markdown]
# # 1. Data
# ## 1.1. OECD Economic Outlook data
#
#
# ### A. Sources: downloaded data from papers
# > ##### a. Boehm(2020, JME)
# * sample period: 1981:1 -2016:4
# * CGV and IGV
#
# > ##### b. Auerbach and Gorodnichenko(2013, AEAPP)
# * sample period: semi-annual, 2004:H1-2011:H2
#   * **should be modified to match quarterly data**
# * CGV
# * Used in Huidrom et al.(2020, JME)
#
#
#
#
#
# ### B. Format
# ##### 1. Forecast error
# * FE_h_x
# * h=horizon, x= government spending components(CGV(gon consumption) or IGV(gov investment)
#
# ##### 2. Forecast revision
# * rev_h_x
# * h=horizon, x= government spending components(CGV(gon consumption)

# %%
# import EO data 
data =  pd.read_excel('data_EO_1.xlsx').sort_values(by=['isocode', 'quarter']).reset_index(drop=True)

data
# Out:
#             country isocode    quarter  region  income  oecd  g7  tradeopen  \
# 0         Argentina     ARG 1950-01-01       7       2   NaN NaN        NaN
# 1         Argentina     ARG 1950-04-01       7       2   NaN NaN        NaN
# 2         Argentina     ARG 1950-07-01       7       2   NaN NaN        NaN
# 3         Argentina     ARG 1950-10-01       7       2   NaN NaN        NaN
# 4         Argentina     ARG 1951-01-01       7       2   NaN NaN        NaN
# ...             ...     ...        ...     ...     ...   ...  ..        ...
# 14495  South Africa     ZAF 2021-04-01       5       2   NaN NaN    55.2194
# 14496  South Africa     ZAF 2021-07-01       5       2   NaN NaN    57.4124
# 14497  South Africa     ZAF 2021-10-01       5       2   NaN NaN    59.4472
# 14498  South Africa     ZAF 2022-01-01       5       2   NaN NaN    61.1930
# 14499  South Africa     ZAF 2022-04-01       5       2   NaN NaN    63.7247
#
#        finopen_ci  finopen_ci_n  ...  rev_18_IGV  rev_19_IGV  rev_20_IGV  \
# 0             NaN           NaN  ...         NaN         NaN         NaN
# 1             NaN           NaN  ...         NaN         NaN         NaN
# 2             NaN           NaN  ...         NaN         NaN         NaN
# 3             NaN           NaN  ...         NaN         NaN         NaN
# 4             NaN           NaN  ...         NaN         NaN         NaN
# ...           ...           ...  ...         ...         ...         ...
# 14495         NaN           NaN  ...         NaN         NaN         NaN
# 14496         NaN           NaN  ...         NaN         NaN         NaN
# 14497         NaN           NaN  ...         NaN         NaN         NaN
# 14498         NaN           NaN  ...         NaN         NaN         NaN
# 14499         NaN           NaN  ...         NaN         NaN         NaN
#
#        year  year_half  time  rev_H0  rev_H1  FE_0  FE_1
# 0       NaN        NaN   NaN     NaN     NaN   NaN   NaN
# 1       NaN        NaN   NaN     NaN     NaN   NaN   NaN
# 2       NaN        NaN   NaN     NaN     NaN   NaN   NaN
# 3       NaN        NaN   NaN     NaN     NaN   NaN   NaN
# 4       NaN        NaN   NaN     NaN     NaN   NaN   NaN
# ...     ...        ...   ...     ...     ...   ...   ...
# 14495   NaN        NaN   NaN     NaN     NaN   NaN   NaN
# 14496   NaN        NaN   NaN     NaN     NaN   NaN   NaN
# 14497   NaN        NaN   NaN     NaN     NaN   NaN   NaN
# 14498   NaN        NaN   NaN     NaN     NaN   NaN   NaN
# 14499   NaN        NaN   NaN     NaN     NaN   NaN   NaN
#
# [14500 rows x 71 columns]

# %%
# number of countries & sample period

print('number of countries:', data['isocode'].unique().shape[0])
print(data['isocode'].unique())
print('start:', np.min(data['quarter'].unique()))
print('end:', np.max(data['quarter'].unique()))

data.info()
# Out:
# number of countries: 50
# ['ARG' 'AUS' 'AUT' 'BEL' 'BGR' 'BRA' 'CAN' 'CHE' 'CHL' 'COL' 'CYP' 'CZE'
#  'DEU' 'DNK' 'ESP' 'EST' 'FIN' 'FRA' 'GBR' 'GRC' 'HKG' 'HRV' 'HUN' 'IDN'
#  'IND' 'IRL' 'ISR' 'ITA' 'JPN' 'KOR' 'LTU' 'LUX' 'LVA' 'MEX' 'MLT' 'NLD'
#  'NOR' 'NZL' 'POL' 'PRT' 'ROU' 'RUS' 'SGP' 'SVK' 'SVN' 'SWE' 'THA' 'TUR'
#  'USA' 'ZAF']
# start: 1950-01-01T00:00:00.000000000
# end: 2022-04-01T00:00:00.000000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14500 entries, 0 to 14499
# Data columns (total 71 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country        14500 non-null  object
#  1   isocode        14500 non-null  object
#  2   quarter        14500 non-null  datetime64[ns]
#  3   region         14500 non-null  int64
#  4   income         14500 non-null  int64
#  5   oecd           10440 non-null  float64
#  6   g7             2030 non-null   float64
#  7   tradeopen      6191 non-null   float64
#  8   finopen_ci     8600 non-null   float64
#  9   finopen_ci_n   8600 non-null   float64
#  10  finopen_fa     9292 non-null   float64
#  11  fxflex_fine    13400 non-null  float64
#  12  fxflex_coarse  13400 non-null  float64
#  13  ggdebt         5587 non-null   float64
#  14  ggcon          6442 non-null   float64
#  15  gdp            6389 non-null   float64
#  16  reer           7591 non-null   float64
#  17  ca             6086 non-null   float64
#  18  pcon           6131 non-null   float64
#  19  cds            3616 non-null   float64
#  20  FE_1_CGV       871 non-null    float64
#  21  FE_1_IGV       815 non-null    float64
#  22  rev_0_CGV      2293 non-null   float64
#  23  rev_1_CGV      2276 non-null   float64
#  24  rev_2_CGV      2259 non-null   float64
#  25  rev_3_CGV      2242 non-null   float64
#  26  rev_4_CGV      2225 non-null   float64
#  27  rev_5_CGV      2208 non-null   float64
#  28  rev_6_CGV      2191 non-null   float64
#  29  rev_7_CGV      2174 non-null   float64
#  30  rev_8_CGV      2157 non-null   float64
#  31  rev_9_CGV      2140 non-null   float64
#  32  rev_10_CGV     2123 non-null   float64
#  33  rev_11_CGV     2106 non-null   float64
#  34  rev_12_CGV     2089 non-null   float64
#  35  rev_13_CGV     2072 non-null   float64
#  36  rev_14_CGV     2055 non-null   float64
#  37  rev_15_CGV     2038 non-null   float64
#  38  rev_16_CGV     2021 non-null   float64
#  39  rev_17_CGV     2004 non-null   float64
#  40  rev_18_CGV     1987 non-null   float64
#  41  rev_19_CGV     1970 non-null   float64
#  42  rev_20_CGV     1953 non-null   float64
#  43  rev_0_IGV      2235 non-null   float64
#  44  rev_1_IGV      2218 non-null   float64
#  45  rev_2_IGV      2201 non-null   float64
#  46  rev_3_IGV      2184 non-null   float64
#  47  rev_4_IGV      2167 non-null   float64
#  48  rev_5_IGV      2150 non-null   float64
#  49  rev_6_IGV      2133 non-null   float64
#  50  rev_7_IGV      2116 non-null   float64
#  51  rev_8_IGV      2099 non-null   float64
#  52  rev_9_IGV      2082 non-null   float64
#  53  rev_10_IGV     2065 non-null   float64
#  54  rev_11_IGV     2048 non-null   float64
#  55  rev_12_IGV     2031 non-null   float64
#  56  rev_13_IGV     2014 non-null   float64
#  57  rev_14_IGV     1997 non-null   float64
#  58  rev_15_IGV     1980 non-null   float64
#  59  rev_16_IGV     1963 non-null   float64
#  60  rev_17_IGV     1946 non-null   float64
#  61  rev_18_IGV     1929 non-null   float64
#  62  rev_19_IGV     1912 non-null   float64
#  63  rev_20_IGV     1895 non-null   float64
#  64  year           3132 non-null   float64
#  65  year_half      3132 non-null   float64
#  66  time           3132 non-null   float64
#  67  rev_H0         1007 non-null   float64
#  68  rev_H1         997 non-null    float64
#  69  FE_0           939 non-null    float64
#  70  FE_1           907 non-null    float64
# dtypes: datetime64[ns](1), float64(66), int64(2), object(2)
# memory usage: 7.9+ MB

# %%
# descriptive statistics

pd.options.display.float_format = '{:.4f}'.format
round(data[['ggdebt', 'ggcon', 'gdp', 'reer', 'ca', 'pcon', 'cds', 'FE_1_CGV', 'FE_1_IGV', 'rev_4_CGV', 'rev_4_IGV', 'rev_20_CGV', 'rev_20_IGV' ]].describe(), 2)
# Out:
#          ggdebt                ggcon                   gdp      reer  \
# count 5587.0000            6442.0000             6389.0000 7591.0000
# mean    55.9600   4532532484647.4199   38866750643511.4688   97.4300
# std     34.4500  21624065103603.4688  234588086412315.8438   19.1000
# min      3.6800           29940.8600       1309589293.3700   32.4200
# 25%     31.7900     10819697477.8500      55490076984.7400   89.7800
# 50%     48.3300     53732045822.3500     267664960565.1500   97.9400
# 75%     71.9400    194813015692.2100     768761357303.6100  103.8500
# max    227.1800 251067293692856.6875 2896892682330298.0000  281.9200
#
#              ca                  pcon        cds  FE_1_CGV  FE_1_IGV  \
# count 6086.0000             6131.0000  3616.0000  871.0000  815.0000
# mean    -0.0800   23000562720867.8594   210.8800    6.0200    0.0200
# std      5.5100  133911320765830.5781   760.8600   10.9600    0.0900
# min    -47.7600        815770839.9200     1.7700 -101.6500   -0.9500
# 25%     -3.1300      29285201853.6500    30.9800    1.3400   -0.0000
# 50%     -0.7200     153703649530.0100    73.2600    6.0600    0.0200
# 75%      2.4400     476742224468.7500   177.4400   11.0800    0.0400
# max     32.6100 1559219424873803.0000 26089.2000  183.2700    0.7000
#
#        rev_4_CGV  rev_4_IGV  rev_20_CGV  rev_20_IGV
# count  2225.0000  2167.0000   1953.0000   1895.0000
# mean      0.3800     0.0700      1.7300      0.4000
# std       0.5000     0.4400      1.5700      0.9900
# min      -1.9200    -2.6700     -3.5900     -3.2800
# 25%       0.1000    -0.1300      0.8500     -0.0900
# 50%       0.3700     0.0600      1.6200      0.3300
# 75%       0.6700     0.2600      2.6200      0.8100
# max       2.4600     3.3400      8.8800      4.3900

# %%
# 

data = data.rename(columns={'country':'country', 'isocode':'isocode', 'quarter':'quarter', 'FE_1_CGV':'FE', 'rev_4_CGV':'FR'})

# %%
for i in range(0, data['isocode'].unique().shape[0]):
  
    globals()['cond_isocode_{}'.format(i+1)] = (data['isocode'] == data['isocode'].unique()[i])
    globals()['df_isocode_{}'.format(i+1)] = data.loc[globals()['cond_isocode_{}'.format(i+1)]]
    globals()['df_isocode_count_T_{}'.format(i+1)] = globals()['df_isocode_{}'.format(i+1)].groupby(globals()['df_isocode_{}'.format(i+1)]['quarter']).count()

    globals()['cond_inv_{}'.format(i+1)] = (globals()['df_isocode_count_T_{}'.format(i+1)]['FE'] == 0)
    globals()['df_isocode_count_T_{}'.format(i+1)] = globals()['df_isocode_count_T_{}'.format(i+1)].loc[~globals()['cond_inv_{}'.format(i+1)]]
    globals()['df_isocode_count_T_{}'.format(i+1)] = globals()['df_isocode_count_T_{}'.format(i+1)].reset_index()
    
    if globals()['df_isocode_count_T_{}'.format(i+1)]['quarter'].unique().shape[0] == 0:

       continue

    else:
       print('country', data['country'].unique()[i])
       print('isocode', data['isocode'].unique()[i])
       print('end:', globals()['df_isocode_count_T_{}'.format(i+1)]['quarter'].unique().max())
       print('obs.:', globals()['df_isocode_count_T_{}'.format(i+1)]['FE'].count())
       print('des. stat.', globals()['df_isocode_{}'.format(i+1)]['FE'].describe())

       plt.figure(figsize=(20, 250)).set_facecolor('white')
       plt.style.use('seaborn-whitegrid')

       plt.subplot(data['isocode'].unique().shape[0], 1, i+1)
       plt.title('Forecast data({})'.format(data['country'].unique()[i]), fontsize=15)
       plt.plot(globals()['df_isocode_{}'.format(i+1)]['quarter'], globals()['df_isocode_{}'.format(i+1)]['FE'], label="Forecast Error", color='royalblue', alpha=0.7)
       plt.plot(globals()['df_isocode_{}'.format(i+1)]['quarter'], globals()['df_isocode_{}'.format(i+1)]['FR'], label="Forecast Revision", color='blue', linestyle = 'dashed',  alpha=0.7)

       plt.xlabel('Time', fontsize=15)
       plt.ylabel('percent', fontsize=15)
       plt.xlim([dt.date(2000, 1, 1), dt.date(2023, 4, 1)])
       plt.ylim()
       plt.xticks(fontsize=12)
       plt.yticks(fontsize=12)
       plt.legend(loc='upper left', ncol=1, fontsize=15)

       plt.tight_layout()
       print('')
# Out:
# country Australia
# isocode AUS
# end: 2016-10-01T00:00:00.000000000
# obs.: 52
# des. stat. count   52.0000
# mean     8.5813
# std      5.4844
# min     -2.2887
# 25%      4.2357
# 50%      9.0955
# 75%     13.8944
# max     15.7381
# Name: FE, dtype: float64
#
# country Belgium
# isocode BEL
# end: 2016-10-01T00:00:00.000000000
# obs.: 50
# des. stat. count   50.0000
# mean     7.1231
# std      4.7190
# min     -4.0240
# 25%      4.8980
# 50%      8.5706
# 75%      9.9151
# max     15.0978
# Name: FE, dtype: float64
#
# country Canada
# isocode CAN
# end: 2016-10-01T00:00:00.000000000
# obs.: 52
# des. stat. count   52.0000
# mean     8.3992
# std      6.8847
# min     -2.5376
# 25%      2.1541
# 50%      9.4214
# 75%     15.2743
# max     20.7989
# Name: FE, dtype: float64
#
# country Germany
# isocode DEU
# end: 2016-10-01T00:00:00.000000000
# obs.: 52
# des. stat. count   52.0000
# mean     5.7388
# std      4.2870
# min     -2.4248
# 25%      3.6974
# 50%      6.2504
# 75%      8.3361
# max     14.3854
# Name: FE, dtype: float64
#
# country Denmark
# isocode DNK
# end: 2015-07-01T00:00:00.000000000
# obs.: 41
# des. stat. count   41.0000
# mean     5.2123
# std      6.3996
# min     -6.7715
# 25%      1.3366
# 50%      4.8807
# 75%      6.8226
# max     26.7286
# Name: FE, dtype: float64
#
# country Finland
# isocode FIN
# end: 2016-10-01T00:00:00.000000000
# obs.: 52
# des. stat. count   52.0000
# mean     5.4204
# std      4.8999
# min     -5.2140
# 25%      2.7403
# 50%      4.7752
# 75%      8.0516
# max     18.1906
# Name: FE, dtype: float64
#
# country France
# isocode FRA
# end: 2016-10-01T00:00:00.000000000
# obs.: 52
# des. stat. count   52.0000
# mean     5.2773
# std      3.6604
# min      0.0000
# 25%      2.3749
# 50%      4.8138
# 75%      8.1102
# max     13.7434
# Name: FE, dtype: float64
#
# country United Kingdom
# isocode GBR
# end: 2016-10-01T00:00:00.000000000
# obs.: 52
# des. stat. count    52.0000
# mean      3.8149
# std       9.9580
# min     -12.1228
# 25%      -4.0025
# 50%       4.0485
# 75%       9.2441
# max      42.9687
# Name: FE, dtype: float64
#
# country Ireland
# isocode IRL
# end: 2016-10-01T00:00:00.000000000
# obs.: 52
# des. stat. count    52.0000
# mean      5.4198
# std      14.2418
# min     -18.4411
# 25%      -7.0423
# 50%       2.1414
# 75%      21.6211
# max      26.1914
# Name: FE, dtype: float64
#
# country Japan
# isocode JPN
# end: 2016-10-01T00:00:00.000000000
# obs.: 52
# des. stat. count   52.0000
# mean     5.7711
# std      6.8014
# min     -4.4432
# 25%      0.9396
# 50%      5.5104
# 75%      9.3087
# max     38.9009
# Name: FE, dtype: float64
#
# country Korea, Rep.
# isocode KOR
# end: 2016-10-01T00:00:00.000000000
# obs.: 52
# des. stat. count    52.0000
# mean     11.1153
# std       8.0516
# min     -16.3482
# 25%       9.6299
# 50%      13.3129
# 75%      15.2756
# max      32.8735
# Name: FE, dtype: float64
#
# country Netherlands
# isocode NLD
# end: 2016-10-01T00:00:00.000000000
# obs.: 52
# des. stat. count    52.0000
# mean      5.4051
# std      26.2792
# min     -32.7326
# 25%      -2.5034
# 50%       2.8656
# 75%       6.8873
# max     183.2652
# Name: FE, dtype: float64
#
# country Norway
# isocode NOR
# end: 2016-10-01T00:00:00.000000000
# obs.: 52
# des. stat. count    52.0000
# mean     12.9653
# std       7.5733
# min     -10.4290
# 25%       9.9931
# 50%      12.9553
# 75%      16.1925
# max      36.7658
# Name: FE, dtype: float64
#
# country New Zealand
# isocode NZL
# end: 2016-10-01T00:00:00.000000000
# obs.: 52
# des. stat. count    52.0000
# mean      7.0469
# std      10.9423
# min     -27.1825
# 25%       1.0581
# 50%       8.8486
# 75%      15.5240
# max      22.9628
# Name: FE, dtype: float64
#
# country Portugal
# isocode PRT
# end: 2016-10-01T00:00:00.000000000
# obs.: 52
# des. stat. count     52.0000
# mean      -6.9878
# std       16.2883
# min     -101.6529
# 25%      -12.0116
# 50%       -4.3546
# 75%        1.4421
# max       13.5839
# Name: FE, dtype: float64
#
# country Sweden
# isocode SWE
# end: 2016-10-01T00:00:00.000000000
# obs.: 52
# des. stat. count   52.0000
# mean     7.5324
# std      4.2623
# min      1.1359
# 25%      5.4795
# 50%      6.8638
# 75%      9.1896
# max     22.6749
# Name: FE, dtype: float64
#
# country United States
# isocode USA
# end: 2016-10-01T00:00:00.000000000
# obs.: 52
# des. stat. count   52.0000
# mean     4.3446
# std      4.9215
# min     -3.4890
# 25%     -0.2718
# 50%      4.7881
# 75%      7.4852
# max     15.5837
# Name: FE, dtype: float64
